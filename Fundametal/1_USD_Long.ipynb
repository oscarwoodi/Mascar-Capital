# %% [markdown]
# ## *Trade Idea 1*

# %% [markdown]
# **Asset**: USD/CHF [Long]
#
# **Entry Point**: USD/CHF 0.8458 (Market)
#
# **Limit**: USD/CHF 0.843
#
# **Stop Loss**: USD/CHF 0.869
#
# **Time Horizon**: Next Fed meeting
#
# **Expected PnL**: 10m x 0.869/0.8458 - 10 = 0.27m

# %% [markdown]
# **Thesis**:
# 1. Based on most recent fed speech, main focus on max employment, stable prices, easing inflation
#
# 2. Given declines in inflation near target and strong economic signals, large rate cut to kick off
#
# > *'Growth of consumer spending resilient, and unemployment up but still low at 4.2%'*
#
# 3. 'Labor market not a source of elevated inflationary pressure' -> wage price spiral not a risk so higher employment encouraged
#
# > *'Upside risk to inflation have diminished but downside to employment have increased'*
#
# 4. Focus has shifted to strength in the economy and lowering rates to subdue unemployment.
#
# > *'Reduing too fast could hinder progress on inflation, and too slow weakens economic activity/employment'*
#
# 5. Still a fine balance between inflation and jobs so although large intial cut, still cautious for further large cuts given that
# everything is already going to plan (strong economy, lowering inflation, lowering unemployment - don't fix what ain't broke?).
#
# 6. Fed funds expected 4.4% by end of year -> no large rush to cut with a handful of meetings left. \
#
# > *'Labour down or inflation falling too fast we can act'*
#
# 7. Dovish response but the two are falling slowly so no rush.
#
# > *'Very patient about reducing rates'*
#
# 8. Unlikely to unwind very fast but a strong initial rate to show their new objective to markets.
#
# 9. **A smaller rate cut to keep with narrative, but maintain caution while they assess the results of the intial cut**
#
# 10. Consensus is a larger 50bps cut, we think 25bps -> stronger interest rates than expected.
#
# 11. Furthermore, historical large cuts then smaller while impact is assessed.
#
# **TRADE: Long Dollar!! (not equities as change muted to expectations in interest rate recently)**

# %% [markdown]
# ### Technical Analysis

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image
img = mpimg.imread('images/1.png')

# Display the image
fig, ax = plt.subplots(figsize=(14, 14))
imgplot = ax.imshow(img)
plt.show()
