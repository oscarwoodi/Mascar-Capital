# %%
"""
This notebook explores the use of News API to get different news articles

Author: Oscar Wooding
Date: Oct 2024
"""

# Imports
import requests
import json

# Variables
API_KEY = '26e7c91f98fa4e76ba840748489820f3'
TOPIC = 'cvx'
SORT_BY = 'date'
START_DATE = '2024-09-08'
URL_SPEC = 'https://newsapi.org/v2/everything?' # news articles that mention a specific topic or keyword
URL_TOP = 'https://newsapi.org/v2/top-headlines?' # current top headlines for a country or category
COUNTRY = 'US'

params_spec = {
    "q": TOPIC, 
    "from": START_DATE, 
    "sortBy": SORT_BY,
    "apiKey": API_KEY
}

param_top = {
    "country": COUNTRY, 
    "apiKey": API_KEY
}

# %%
# news articles that mention a specific topic or keyword
r = requests.get(url=URL_SPEC, params=params_spec)
print(r.status_code)
stock_values = r.json()
stock_values
# Out:
# 200
# {'status': 'ok',
#  'totalResults': 200,
#  'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Neha Gupta',
#    'title': 'Chevron Corporation (CVX): Warren Buffett’s Stock Recommended by Analysts',
#    'description': 'We recently compiled a list of the 8 Best Warren Buffett Stocks to Buy According to Analysts. In this article, we are going to take a look at where Chevron...',
#    'url': 'https://finance.yahoo.com/news/chevron-corporation-cvx-warren-buffett-220901301.html/',
#    'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png',
#    'publishedAt': '2024-09-30T22:09:01Z',
#    'content': 'We recently compiled a list of the\xa08 Best Warren Buffett Stocks to Buy According to Analysts.\xa0In this article, we are going to take a look at where Chevron Corporation (NYSE:CVX) stands against the o… [+7467 chars]'},
#   {'source': {'id': None, 'name': 'Quartz India'},
#    'author': 'Rocio Fabbro',
# ...

# %%
12570 - 0.5*18000
# Out:
# 3570.0
